# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import pandas_datareader.data as web 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style( "whitegrid" )
% matplotlib inline
from datetime import datetime
from __future__ import division

# %%
stock_lis = [ "AAPL" , "GOOG" , "MSFT" , "AMZN" ]
end = datetime.now()
start = datetime(end.year - 1 ,end.month,end.day)
for stock in stock_lis:
    globals()[stock] = web.DataReader(stock, "yahoo" ,start,end)
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-16-ad1af82f67a7> in <module>()
#       3 start = datetime(end.year - 1 ,end.month,end.day)
#       4 for stock in stock_lis:
# ----> 5     globals()[stock] = web.DataReader(stock, "yahoo" ,start,end)
#
# ~/anaconda/lib/python3.6/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     119                                 adjust_price=False, chunksize=25,
#     120                                 retry_count=retry_count, pause=pause,
# --> 121                                 session=session).read()
#     122
#     123     elif data_source == "yahoo-actions":
#
# ~/anaconda/lib/python3.6/site-packages/pandas_datareader/yahoo/daily.py in read(self)
#     113         """ read one data from specified URL """
#     114         try:
# ...

# %%
AAPL.head()

# %%
AAPL.describe()

# %%
AAPL.info()

# %%
AAPL[ "Adj Close" ].plot(legend = True ,figsize = ( 10 , 4 ))

# %%
AAPL[ "Volume" ].plot(legend = True ,figsize = ( 10 , 4 ))

# %%
import tushare

print(tushare.__version__)
# Out:
# 0.8.7

# %%
import tushare as ts

ts.get_hist_data('601111')
# Out:
#             open  high  close   low      volume  price_change  p_change  \
# date
# 2017-08-22  9.15  9.18   9.11  9.08   374447.47         -0.03     -0.33
# 2017-08-21  9.36  9.39   9.14  9.10   551953.25         -0.16     -1.72
# 2017-08-18  9.24  9.39   9.30  9.12   541283.06          0.05      0.54
# 2017-08-17  9.07  9.40   9.25  9.07   843713.62          0.23      2.55
# 2017-08-16  9.02  9.07   9.02  8.89   337896.91         -0.04     -0.44
# 2017-08-15  9.10  9.13   9.06  9.00   301052.00         -0.05     -0.55
# 2017-08-14  9.05  9.12   9.11  8.93   472569.41          0.00      0.00
# 2017-08-11  9.08  9.16   9.11  8.90   743596.75          0.04      0.44
# 2017-08-10  8.85  9.26   9.07  8.85  1234973.25          0.36      4.13
# 2017-08-09  8.71  8.72   8.71  8.56   344803.03          0.01      0.12
# 2017-08-08  8.69  8.74   8.70  8.59   239604.08          0.00      0.00
# 2017-08-07  8.61  8.71   8.70  8.56   161759.94          0.02      0.23
# ...

# %%
import pandas as pd
ma_day = [ 10 , 20 , 50 ]
for ma in ma_day:
    column_name = "MA for %s days" % ( str (ma))
    AAPL[column_name]=AAPL[ "Adj Close" ].rolling(ma)

# %%
AAPL[ 10 : 15 ]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-09-07  107.830002  108.760002  107.070000  108.360001  106.481720
# 2016-09-08  107.250000  107.269997  105.239998  105.519997  103.690956
# 2016-09-09  104.639999  105.720001  103.129997  103.129997  101.342369
# 2016-09-12  102.650002  105.720001  102.529999  105.440002  103.612335
# 2016-09-13  107.510002  108.790001  107.239998  107.949997  106.078827
#
#               Volume                           MA for 10 days  \
# Date
# 2016-09-07  42364300  Rolling [window=10,center=False,axis=0]
# 2016-09-08  53002000  Rolling [window=10,center=False,axis=0]
# 2016-09-09  46557000  Rolling [window=10,center=False,axis=0]
# 2016-09-12  45292800  Rolling [window=10,center=False,axis=0]
# 2016-09-13  62176200  Rolling [window=10,center=False,axis=0]
#
#                                      MA for 20 days  \
# Date
# 2016-09-07  Rolling [window=20,center=False,axis=0]
# ...

# %%
AAPL[[ "Adj Close" , "MA for 10 days" , "MA for 20 days" , "MA for 50 days" ]].plot(subplots = True )
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1148dc400>], dtype=object)

# %%
AAPL[[ "Adj Close" , "MA for 10 days" , "MA for 20 days" , "MA for 50 days" ]].plot(figsize = ( 10 , 4 ))

# %%
AAPL[ "Dailly Return" ] = AAPL[ "Adj Close" ].pct_change()
###plot一下
AAPL[ "Dailly Return" ].plot(figsize = ( 10 , 4 ),legend = True )

# %%
AAPL[ "Dailly Return" ].plot(figsize = ( 10 , 4 ),legend = True ,linestyle = "--" ,marker = "o" )

# %%
sns.kdeplot(AAPL[ "Dailly Return" ].dropna())

# %%
sns.jointplot( "GOOG" , "GOOG" ,tech_rets,kind = "hex" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-346b564354dd> in <module>()
# ----> 1 sns.jointplot( "GOOG" , "GOOG" ,tech_rets,kind = "hex" )
#
# NameError: name 'tech_rets' is not defined

# %%
ts.get_hist_data('601111',start='2017-08-22',end='2017-08-23')
# Out:
#             open  high  close   low     volume  price_change  p_change    ma5  \
# date
# 2017-08-22  9.15  9.18   9.11  9.08  374447.47         -0.03     -0.33  9.164
#
#              ma10   ma20      v_ma5     v_ma10     v_ma20  turnover
# date
# 2017-08-22  9.088  8.912  529858.86  574628.88  441224.77      0.44

# %%
ts.get_hist_data('601111', ktype='W') #获取周k线数据
ts.get_hist_data('601111', ktype='M') #获取月k线数据
ts.get_hist_data('601111', ktype='5') #获取5分钟k线数据
ts.get_hist_data('601111', ktype='15') #获取15分钟k线数据
ts.get_hist_data('601111', ktype='30') #获取30分钟k线数据
ts.get_hist_data('601111', ktype='60') #获取60分钟k线数据
ts.get_hist_data('sh'）#获取上证指数k线数据，其它参数与个股一致，下同
ts.get_hist_data('sz'）#获取深圳成指k线数据
ts.get_hist_data('hs300'）#获取沪深300指数k线数据
ts.get_hist_data('sz50'）#获取上证50指数k线数据
ts.get_hist_data('zxb'）#获取中小板指数k线数据
ts.get_hist_data('cyb'）#获取创业板指数k线数据
# Out:
#   File "<ipython-input-39-677cd61f4beb>", line 2
#     ts.get_hist_data('sz'）#获取深圳成指k线数据
#                          ^
# SyntaxError: invalid character in identifier

# %%
df = ts.get_stock_basics()
date = df.ix['601111']['timeToMarket'] #上市日期YYYYMMDD

# %%
ts.get_h_data('601111') #前复权
ts.get_h_data('601111', autype='hfq') #后复权
ts.get_h_data('601111', autype=None) #不复权
ts.get_h_data('601111', start='2015-01-01', end='2015-03-16') #两个日期之间的前复权数据

ts.get_h_data('399106', index=True) #深圳综合指数
