# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import pandas_datareader.data as web 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style( "whitegrid" )
% matplotlib inline
from datetime import datetime
from __future__ import division

# %%
stock_lis = [ "AAPL" , "GOOG" , "MSFT" , "AMZN" ]
end = datetime.now()
start = datetime(end.year - 1 ,end.month,end.day)
for stock in stock_lis:
    globals()[stock] = web.DataReader(stock, "yahoo" ,start,end)

# %%
AAPL.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-08-23  108.589996  109.320000  108.529999  108.849998  106.963219
# 2016-08-24  108.570000  108.750000  107.680000  108.029999  106.157440
# 2016-08-25  107.389999  107.879997  106.680000  107.570000  105.705414
# 2016-08-26  107.410004  107.949997  106.309998  106.940002  105.086334
# 2016-08-29  106.620003  107.440002  106.290001  106.820000  104.968414
#
#               Volume
# Date
# 2016-08-23  21257700
# 2016-08-24  23675100
# 2016-08-25  25086200
# 2016-08-26  27766300
# 2016-08-29  24970300

# %%
AAPL.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   131.605278  132.519008  130.772976  131.736508  130.538672
# std     17.419628   17.436654   17.251863   17.324879   17.777722
# min    102.650002  105.720001  102.529999  103.129997  101.342369
# 25%    114.402498  115.827501  113.690000  114.844999  112.854311
# 50%    136.329994  136.934998  136.044999  136.680001  135.585724
# 75%    145.537502  146.772503  144.662503  145.822506  145.252106
# max    161.940002  162.509995  160.149994  161.600006  161.600006
#
#              Volume
# count  2.520000e+02
# mean   2.964216e+07
# std    1.386759e+07
# min    9.709658e+06
# 25%    2.138520e+07
# 50%    2.618695e+07
# 75%    3.342158e+07
# max    1.119850e+08

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2016-08-23 to 2017-08-22
# Data columns (total 6 columns):
# Open         252 non-null float64
# High         252 non-null float64
# Low          252 non-null float64
# Close        252 non-null float64
# Adj Close    252 non-null float64
# Volume       252 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %%
AAPL[ "Adj Close" ].plot(legend = True ,figsize = ( 10 , 4 ))

# %%
AAPL[ "Volume" ].plot(legend = True ,figsize = ( 10 , 4 ))
